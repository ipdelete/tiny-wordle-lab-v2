# %% [markdown]
# # Lab 09 — Distillation
#
# Transfer better strategic behavior from an expert.
#
# **Intentionally not expanded yet.** Later labs should respond to evidence from earlier experiments, not pretend the interesting failure mode is known in advance.
